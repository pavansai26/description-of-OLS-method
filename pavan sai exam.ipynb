# %%
import numpy as np
import pandas as pd
import seaborn as sns
import statsmodels.api as sm
from sklearn.model_selection import train_test_split

# %% [markdown]
# # 1) write a function "prime" which will give output like the following.

# %%
def prime(x):
    for i in range(2,x):
        if x%i==0:
            print('not_prime')
            break
        else:
            print('prime')

# %%
prime(4)
# Out:
# not_prime

# %%
prime(20)
# Out:
# not_prime

# %% [markdown]
# # 2) do the same exercise using  lambda function if you have solved it without using lambda function

# %%
prime(23)
# Out:
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime
# prime

# %%
a=lambda x:'prime' if len([i for i in range(2,x) if x%i==0])==0 else 'not_prime'

# %%
a(99)
# Out:
# 'not_prime'

# %%
prime(20)
# Out:
# not_prime

# %% [markdown]
# # 3)

# %% [markdown]
# # If a word, phrase, or sequence that reads the same backwards as forward  then we call it a palindrome. for example "abba" and "abcba" are palindromes

# %% [markdown]
# # write a function that will detect palindromes like the function

# %%
def reverse(string):
    if string==string[::-1]:
        print('palindrome')
    else:
        print('not palindrome')

# %%
reverse("abcba")
# Out:
# palindrome

# %%
reverse("abcbav")
# Out:
# not palindrome

# %% [markdown]
# # 4) do the same above exercise using lambda function if you have solved it without using lambda function

# %%
a=lambda string:'palindrome' if string==string[::-1] else 'not palindrome'

# %%
a('abvbc')

# %%
palindrome("abcbav")

# %% [markdown]
# # 5)

# %% [markdown]
# # LCM: the smallest number that is a multiple of each of two  numbers

# %% [markdown]
# # implement LCM using lambda function

# %%
LCM(10,15)

# %%
from math import gcd

# %%
g=lambda a,b:(a*b)/max([i for i in range(1,min(a,b)) if a%i==0 and b%i==0])

# %%
g(10,12)
# Out:
# 60.0

# %%
g(10,13)
# Out:
# 130.0

# %% [markdown]
# # 6)

# %%
iris = sns.load_dataset("iris")

# %%
iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 10            5.4          3.7           1.5          0.2      setosa
# 85            6.0          3.4           4.5          1.6  versicolor
# 38            4.4          3.0           1.3          0.2      setosa
# 94            5.6          2.7           4.2          1.3  versicolor
# 59            5.2          2.7           3.9          1.4  versicolor
# 18            5.7          3.8           1.7          0.3      setosa
# 131           7.9          3.8           6.4          2.0   virginica
# 144           6.7          3.3           5.7          2.5   virginica
# 40            5.0          3.5           1.3          0.3      setosa
# 84            5.4          3.0           4.5          1.5  versicolor

# %%
x
for i in iris['species']:
    if i=='versicolor':
        print(1) 
    else:
        print(0)

# %%
iris['versicolor']=x.append(i)

# %%
iris['versicolor']=iris.species.apply(lambda x:1 if x=='versicolor' else 0)
iris['setosa']=iris.species.apply(lambda x:1 if x=='setosa' else 0)
iris['virginica']=iris.species.apply(lambda x:1 if x=='virginica' else 0)

# %% [markdown]
# # make some transformation so that our data looks like the following

# %%
iris.sample(10)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species  \
# 66            5.6          3.0           4.5          1.5  versicolor
# 90            5.5          2.6           4.4          1.2  versicolor
# 41            4.5          2.3           1.3          0.3      setosa
# 138           6.0          3.0           4.8          1.8   virginica
# 140           6.7          3.1           5.6          2.4   virginica
# 72            6.3          2.5           4.9          1.5  versicolor
# 44            5.1          3.8           1.9          0.4      setosa
# 76            6.8          2.8           4.8          1.4  versicolor
# 128           6.4          2.8           5.6          2.1   virginica
# 85            6.0          3.4           4.5          1.6  versicolor
#
#      versicolor  setosa  virginica
# 66            1       0          0
# 90            1       0          0
# 41            0       1          0
# 138           0       0          1
# ...

# %% [markdown]
# # 7) regression analysis

# %% [markdown]
# #

# %%
data.to_csv("exam_prime.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-d1f1075d7114> in <module>
# ----> 1 data.to_csv("exam_prime.csv")
#
# NameError: name 'data' is not defined

# %%
data.head()

# %%
df=pd.read_csv('exam_prime.csv')

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [x1, x2, y]
# Index: []

# %%
x=df.iloc[:,:2]
x.head(0)
# Out:
# Empty DataFrame
# Columns: [x1, x2]
# Index: []

# %%
y=df.iloc[:,-1]

# %%
y=pd.DataFrame(y)

# %% [markdown]
# from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x5,y,test_size=0.3,random_state=89)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()

# %%
y_pred=model.fit(x_train,y_train).predict(x_test)

# %%
x_train.shape

# %%
y_train.shape

# %%
from sklearn.metrics import mean_absolute_error

# %%
mean_absolute_error(y_test,y_pred)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test,y_pred)

# %%
# %time import matplotlib.pyplot as plt

# %%
# %time sns.regplot(y_test,y_pred)

# %%
corr_x=df.corr(method='pearson')
mask=np.zeros_like(corr_x)
mask[np.triu_indices_from(mask)]
sns.heatmap(corr_x,cmap='RdYlGn',annot=True)

# %%
ss=sm.OLS(y,sm.add_constant(x5))

# %%
ss.fit().summary()

# %%
x4

# %%
x5=pd.concat([x1,x2],axis=1)

# %%
x5

# %%
x['x3']=x['x1']*x['x2']

# %%
x3
# Out:
# 0       1.088853
# 1     -25.165019
# 2      -3.334901
# 3      77.448475
# 4      23.191116
# 5     -10.597514
# 6      51.609930
# 7       2.167706
# 8      78.152206
# 9      15.262024
# 10      1.930881
# 11     -2.514045
# 12     31.042090
# 13     -2.408312
# 14    -60.059684
# 15     12.131712
# 16      9.842259
# 17     15.810867
# 18     -0.434058
# 19    -23.582014
# 20     -1.847571
# 21      7.162274
# 22    -16.209639
# 23     70.712372
# 24     -0.579225
# 25    -34.504654
# 26     33.513933
# 27      8.256492
# 28      2.448114
# 29    -50.985585
#          ...
# 270     5.887720
# 271   -29.426461
# 272    15.961726
# 273    -0.510374
# 274   -95.822923
# 275    35.916260
# 276   -12.379729
# 277    50.580847
# 278    15.059780
# 279   -23.348058
# 280   -20.159982
# 281   -19.887859
# 282    67.809659
# 283    32.323174
# 284    17.729723
# 285    15.206105
# 286    47.469008
# 287    -9.802728
# 288     0.881763
# 289    15.140842
# 290    -9.067490
# ...

# %%
x['x4']=x['x2']*x['x2']

# %%
x4
# Out:
# 0      42.073025
# 1      14.572481
# 2       0.246118
# 3      70.269664
# 4      23.450563
# 5       1.769497
# 6      98.973290
# 7       1.164611
# 8      75.999672
# 9      63.617670
# 10      1.036234
# 11      2.589216
# 12     64.437390
# 13      0.242363
# 14     72.488433
# 15     13.377730
# 16     14.530573
# 17     80.552504
# 18     17.302751
# 19      7.713280
# 20      0.823578
# 21      0.931921
# 22     70.605864
# 23     50.229945
# 24      0.025321
# 25     51.781752
# 26     56.616749
# 27     18.100640
# 28      0.063328
# 29     83.001767
#          ...
# 270     6.641499
# 271     9.498077
# 272    23.249883
# 273     0.428278
# 274    94.722320
# 275    39.726618
# 276     2.439915
# 277    52.896081
# 278    28.005590
# 279    24.224951
# 280     6.733738
# 281    46.990481
# 282    50.208825
# 283    12.034190
# 284     5.207296
# 285     7.296971
# 286    22.686659
# 287     1.562363
# 288    46.047327
# 289    13.573891
# 290     2.155260
# ...

# %%
x
# Out:
#            x1        x2         x4         x3
# 0    0.167868  6.486372  42.073025   1.088853
# 1   -6.592202  3.817392  14.572481 -25.165019
# 2    6.722201 -0.496103   0.246118  -3.334901
# 3   -9.239084 -8.382700  70.269664  77.448475
# 4   -4.789002 -4.842578  23.450563  23.191116
# 5    7.966710 -1.330225   1.769497 -10.597514
# 6    5.187693  9.948532  98.973290  51.609930
# 7   -2.008676 -1.079172   1.164611   2.167706
# 8    8.964692  8.717779  75.999672  78.152206
# 9    1.913477  7.976069  63.617670  15.262024
# 10   1.896822  1.017956   1.036234   1.930881
# 11  -1.562388  1.609104   2.589216  -2.514045
# 12   3.867070  8.027290  64.437390  31.042090
# 13  -4.891921  0.492304   0.242363  -2.408312
# 14  -7.054215  8.514014  72.488433 -60.059684
# 15  -3.316889 -3.657558  13.377730  12.131712
# 16  -2.581983 -3.811899  14.530573   9.842259
# 17   1.761636  8.975105  80.552504  15.810867
# 18   0.104350 -4.159658  17.302751  -0.434058
# ...

# %%
sns.pairplot(df)

# %% [markdown]
# 1)from the output of pairplot you can understand that data is not linear.
# 2)if you apply linear regression to this data you will get high error

# %%
sns.distplot(x['x1'])

# %%
for i in x.columns:
    sns.distplot(x[i])

# %% [markdown]
# from this plot you can understand that data is normalized. so you can apply <u>pearson</u> method of correleation

# %%
corr=df.corr(method='pearson')
mask=np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr,cbar=True,cmap='coolwarm',annot=True)

# %% [markdown]
# from this heatmap you can understand that there is much correlation between them

# %%
k=df.merge(x)

# %%
corr=k.corr(method='pearson')
mask=np.zeros_like(corr)
mask[np.triu_indices_from(mask)]=True
sns.heatmap(corr,cbar=True,cmap='coolwarm',annot=True)

# %%
sns.pairplot(k);

# %%
xl=sm.OLS(y,sm.add_constant(x))
# Out:
# C:\Users\lenovo\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py:2389: FutureWarning: Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
#   return ptp(axis=axis, out=out, **kwargs)

# %%
xl.fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.069
# Method:                 Least Squares   F-statistic:                     6.562
# Date:                Sat, 02 Nov 2019   Prob (F-statistic):           4.53e-05
# Time:                        10:12:32   Log-Likelihood:                -1866.7
# No. Observations:                 300   AIC:                             3743.
# Df Residuals:                     295   BIC:                             3762.
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        151.8011     10.325     14.703      0.000     131.482     172.120
# ...

# %% [markdown]
# from the ols regression results Df Residuals:295 (300-4-1) i.e (no.of rows-no.of features-1)
# Df Residuals: means <u>degree of freedom</u>

# %% [markdown]
# Df Model:it indicates the no.of features in the model

# %% [markdown]
# R-square is very low it indicates that error is more

# %% [markdown]
# adjusted R square is less theere is no such features and no.of observations to decrease the error

# %% [markdown]
# Fstatistic it indicates your model is really better than a simple average.or far from zero. we got 6.562 i think it is far from zero

# %% [markdown]
# probability of fstatics it indicates how your model is really better than mean.it should be low.but we gotProb (F-statistic):
# 4.53e-05 it is high

# %% [markdown]
# AIC:
# 3743 AIC is called akaike information criterion.it is a score that evaluates the model based on the no.of observations and complexity of the model.the lesser the AIC score.the model will be better.we got high value.

# %% [markdown]
# BIC:
# 3762 it is same as AIC but it gives high penality for models with more features.

# %% [markdown]
# standard error indicates the how your model is far from mean.it should be low.

# %% [markdown]
# t the statistic value a measure indicating wheather coeff true value is different from zero.it should be low.but we got high value.

# %% [markdown]
# P>|t|the probability of the statistic value a measure indicating wheather coeff true value is different from zero.from ols results the probability is very low.

# %% [markdown]
# Skew:
# 0.573 this is a measure of the symmetry of the residuals around the mean.for symmetric distributed residuals the value should be around zero.but we got positive value it indicates long tail to right.

# %% [markdown]
# Kurtosis:
# 2.207 this is a measure of shape of the distribution of the residuals.a bell shaped distribution has zero measure.
# but we got positive value it indicates distribution has a peak.

# %% [markdown]
# Omnibus:
# 36.460 this is a combined statistical test for both skewnwss and kurtosis.

# %% [markdown]
# Prob(Omnibus):
# 0.000 it indictes the probability of omnibus.

# %% [markdown]
# Jarque-Bera (JB):
# 24.287 this is an another test for the skewness and kurtosis

# %% [markdown]
# Prob(JB):
# 5.32e-06 it indicates the probability of jarque bera

# %% [markdown]
# Durbin-Watson:
# 2.107  this is a test for presence of correlation among the residuals.

# %% [markdown]
# Cond. No.
# 62.1 this is a test for multicolinearity

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model=DecisionTreeRegressor()

# %%
model.fit(x,y)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=None, splitter='best')

# %%
pred=model.predict(x)

# %%
from sklearn import metrics

# %%
metrics.mean_squared_error(y,pred)
# Out:
# 0.0

# %%
metrics.median_absolute_error(y,pred)
# Out:
# 0.0

# %%
sns.regplot(y,pred)
